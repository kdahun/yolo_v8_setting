# %%
from ultralytics import YOLO
import cv2
model = YOLO("yolov8n.pt") # 원하는 크기 모델 입력(n ~ x)

# 모델을 사용해 이미지 예측
result = model.predict(source = "./frame/A_mermaid_tale/*.png", conf=0.7)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\0.png: 384x640 (no detections), 140.7ms
# image 2/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1000.png: 384x640 3 persons, 2 chairs, 2.4ms
# image 3/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1001.png: 384x640 1 person, 17.4ms
# image 4/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1003.png: 384x640 2 persons, 15.7ms
# image 5/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1004.png: 384x640 1 person, 15.7ms
# image 6/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1006.png: 384x640 1 person, 15.7ms
# image 7/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1007.png: 384x640 2 persons, 15.7ms
# image 8/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1009.png: 384x640 2 persons, 15.7ms
# image 9/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\101.png: 384x640 1 truck, 15.7ms
# image 10/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1011.png: 384x640 1 person, 15.7ms
# image 11/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1012.png: 384x640 2 persons, 15.3ms
# image 12/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1014.png: 384x640 1 person, 0.0ms
# image 13/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1015.png: 384x640 2 persons, 1.5ms
# image 14/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1017.png: 384x640 1 person, 0.0ms
# image 15/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1018.png: 384x640 2 persons, 1.5ms
# image 16/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\102.png: 384x640 1 truck, 3.1ms
# image 17/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1020.png: 384x640 2 persons, 5.2ms
# image 18/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1021.png: 384x640 1 person, 4.5ms
# image 19/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1023.png: 384x640 2 persons, 2.3ms
# image 20/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1024.png: 384x640 1 person, 3.3ms
# image 21/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1026.png: 384x640 2 persons, 0.1ms
# image 22/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1027.png: 384x640 2 persons, 0.7ms
# image 23/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1029.png: 384x640 1 person, 0.0ms
# image 24/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1030.png: 384x640 1 person, 1.3ms
# image 25/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1032.png: 384x640 1 person, 1 dog, 0.8ms
# image 26/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1033.png: 384x640 1 car, 2.8ms
# image 27/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1035.png: 384x640 (no detections), 4.9ms
# image 28/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1036.png: 384x640 (no detections), 2.8ms
# image 29/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1038.png: 384x640 1 person, 15.8ms
# image 30/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1039.png: 384x640 1 person, 2.7ms
# image 31/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\104.png: 384x640 (no detections), 0.1ms
# image 32/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1041.png: 384x640 1 person, 3.0ms
# image 33/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1042.png: 384x640 1 person, 1.1ms
# image 34/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1044.png: 384x640 1 person, 2.6ms
# image 35/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1045.png: 384x640 1 person, 0.0ms
# image 36/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1047.png: 384x640 1 person, 0.0ms
# image 37/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1048.png: 384x640 1 person, 0.0ms
# image 38/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\105.png: 384x640 (no detections), 4.9ms
# image 39/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1050.png: 384x640 1 person, 2.8ms
# image 40/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1051.png: 384x640 1 person, 2.1ms
# image 41/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1053.png: 384x640 1 person, 2.8ms
# image 42/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1054.png: 384x640 1 person, 0.0ms
# image 43/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1056.png: 384x640 1 person, 0.0ms
# image 44/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1057.png: 384x640 1 person, 0.0ms
# image 45/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1059.png: 384x640 1 person, 3.8ms
# image 46/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1060.png: 384x640 1 person, 2.6ms
# image 47/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1062.png: 384x640 1 person, 3.7ms
# image 48/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1063.png: 384x640 (no detections), 3.2ms
# image 49/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1065.png: 384x640 1 cell phone, 13.7ms
# image 50/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\1066.png: 384x640 1 person, 14.8ms
# image 51/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\
3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\988.png: 384x640 1 person, 2.3ms
# image 3699/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\989.png: 384x640 2 persons, 4.0ms
# image 3700/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\99.png: 384x640 (no detections), 4.1ms
# image 3701/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\991.png: 384x640 1 person, 4.0ms
# image 3702/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\992.png: 384x640 1 person, 0.0ms
# image 3703/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\994.png: 384x640 1 person, 0.9ms
# image 3704/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\995.png: 384x640 1 person, 2.6ms
# image 3705/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\997.png: 384x640 1 person, 2.7ms
# image 3706/3706 c:\Users\GPUserver\yolov8\frame\A_mermaid_tale\998.png: 384x640 3 persons, 2 chairs, 2.5ms
# Speed: 2.9ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
import os
import shutil

# 폴더 생성
person_predict_folder = "person_predict_maid"
if not os.path.exists(person_predict_folder):
    os.makedirs(person_predict_folder)

person_results=[]
# 결과 처리
for re in result:
    # 각 예측 결과를 반복하여 사람 객체(cls==0)이 있는지 확인
    has_person = any(int(cls) == 0 for cls in re.boxes.cls)

    # 사람 객체가 있는 경우, 해당 이미지를 person_predict 폴더에 복사하여 저장
    if has_person:
        person_results.append(re)
        # 원본 이미지 경로 가져오기
        original_image_path = re.path
        # 파일명만 추출
        file_name = os.path.basename(original_image_path)
        # 새 저장 경로 지정
        new_path = os.path.join(person_predict_folder, file_name)
        # 이미지 복사 및 저장
        shutil.copy(original_image_path, new_path)

# %%
len(person_results)
# Out:
# 2811

# %%
# result 저장하기

import os
import pickle
import re

results_folder = "result_pickle_maid"

if not os.path.exists(results_folder):
    os.makedirs(results_folder)

for res in person_results:
    number = re.sub(r'[^0-9]','',res.path)
    file_path = os.path.join(results_folder,f"result_{number[1:]}.pk1")

    with open(file_path,'wb') as f:
        pickle.dump(res,f)

        
print("Results saved successfully.")

# %%
import re
import matplotlib.pyplot as plt

sorted_result=sorted(os.listdir(results_folder), key=lambda s: int(re.search(r'\d+',s).group()))


# 저장된 모든 Results 객체 불러오기 및 시각화
for filename in sorted_result:
    file_path = os.path.join(results_folder, filename)
    with open(file_path, 'rb') as f:
        loaded_result = pickle.load(f)
        
    # 원본 이미지 가져오기
    original_img = loaded_result.orig_img
    plt.figure()
    plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
    plt.title(filename)
    plt.axis('off')
plt.show()

# %%
import re
import matplotlib.pyplot as plt
import cv2
import os
import pickle

results_folder = "result_pickle_notebook"

# 0, 1, 10, 100 ... 과 같이 정렬되지 않고 0,1,2,3,4... 순으로 정렬되게 하기 위해서
sorted_result=sorted(os.listdir(results_folder), key=lambda s: int(re.search(r'\d+',s).group()))


# 저장된 모든 Results 객체 불러오기 및 시각화
for filename in sorted_result:
    file_path = os.path.join(results_folder, filename)
    with open(file_path, 'rb') as f:
        loaded_result = pickle.load(f)
    count = 0
    
    # cv 때문에 (레퍼런스를 넘겨주기 때문) 원본이미지가 망가지기 때문에 copy를 사용
    original_img = loaded_result.orig_img.copy()

    for box in loaded_result.boxes:
        x1,y1,x2,y2 = box.xyxy[0] # 경계 상자 좌표
        conf = box.conf[0]
        cls = box.cls[0]
        label = loaded_result.names[int(cls)]

        if label == 'person':
            count=count+1
            # 경계 상자 그리기
            cv2.rectangle(original_img, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)
            cv2.putText(original_img, f'{count} {conf:.2f}', (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
            plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
            
    plt.show()
    select_object = int(input())
    if select_object == 0:
        continue
    else:
        x1,y1,x2,y2 = loaded_result.boxes[select_object-1].xyxy[0]
        # cv 때문에 (레퍼런스를 넘겨주기 때문) 원본이미지가 망가지기 때문에 copy를 사용
        original_img = loaded_result.orig_img.copy()
        
        cv2.rectangle(original_img, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)
        cv2.putText(original_img, f'{count} {conf:.2f}', (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
        plt.figure()
        plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
        plt.show()

# %%
cls = result[0].boxes[1].cls[0]
label = result[0].names[int(cls)]
label

# %%
import re
import matplotlib.pyplot as plt
import cv2
import os
import pickle

results_folder = "result_pickle_notebook"

# 0, 1, 10, 100 ... 과 같이 정렬되지 않고 0, 1, 2, 3, 4... 순으로 정렬되게 하기 위해서
sorted_result = sorted(os.listdir(results_folder), key=lambda s: int(re.search(r'\d+', s).group()))

# 저장된 모든 Results 객체 불러오기 및 시각화
for filename in sorted_result:
    file_path = os.path.join(results_folder, filename)
    with open(file_path, 'rb') as f:
        loaded_result = pickle.load(f)
    
    count = 0
    original_img = loaded_result.orig_img.copy()  # 원본 이미지 복사

    for box in loaded_result.boxes:
        x1, y1, x2, y2 = box.xyxy[0]  # 경계 상자 좌표
        conf = box.conf[0]
        cls = box.cls[0]
        label = loaded_result.names[int(cls)]

        if label == 'person':
            count += 1
            make_box(box,count,original_img)
            ########################################
            # # 경계 상자 그리기
            # cv2.rectangle(original_img, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)
            
            # # 텍스트 위치 계산 및 조정
            # text = f'object : {count}, acc : {conf:.2f}'
            # font_scale = 2.0  # 텍스트 크기 조정
            # font_thickness = 4  # 텍스트 두께 조정
            # text_size, _ = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, font_scale, font_thickness)
            # text_w, text_h = text_size
            # text_x = int(x1)
            # text_y = int(y1) - 10
            
            # if text_y < text_h:
            #     text_y = int(y1) + text_h + 10
            
            # # 텍스트 배경 그리기
            # cv2.rectangle(original_img, (text_x, text_y - text_h), (text_x + text_w, text_y), (255, 0, 0), -1)
            # # 텍스트 그리기
            # cv2.putText(original_img, text, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (255, 255, 255), font_thickness)
            #############################################

    # 그림을 초기화하고 이미지 표시
    plt.figure()
    plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
    plt.show()

    select_object = int(input("Select object number (0 to continue): "))
    if select_object == 0:
        continue
    else:
        x1, y1, x2, y2 = loaded_result.boxes[select_object-1].xyxy[0]
        selected_img = loaded_result.orig_img.copy()

        make_box(loaded_result.boxes[select_object-1],select_object,selected_img)
        ########################################
        # cv2.rectangle(selected_img, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)
        
        # text = f'object : {select_object}, acc : {conf:.2f}'
        # font_scale = 2.0  # 텍스트 크기 조정
        # font_thickness = 4  # 텍스트 두께 조정
        # text_size, _ = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, font_scale, font_thickness)
        # text_w, text_h = text_size
        # text_x = int(x1)
        # text_y = int(y1) - 10
        
        # if text_y < text_h:
        #     text_y = int(y1) + text_h + 10
        
        # # 텍스트 배경 그리기
        # cv2.rectangle(selected_img, (text_x, text_y - text_h), (text_x + text_w, text_y), (255, 0, 0), -1)
        # # 텍스트 그리기
        # cv2.putText(selected_img, text, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (255, 255, 255), font_thickness)
        ########################################

        # 그림을 초기화하고 이미지 표시
        plt.figure()
        plt.imshow(cv2.cvtColor(selected_img, cv2.COLOR_BGR2RGB))
        plt.show()

# %%
import re
import matplotlib.pyplot as plt
import cv2
import os
import pickle


# label의 배경과 글자 크기 설정 메서드
def make_box(result,count,original_img):
    x1, y1, x2, y2 = result.xyxy[0]  # 경계 상자 좌표
    conf = result.conf[0]
    cls = result.cls[0]
    label = loaded_result.names[int(cls)]
    # 경계 상자 그리기
    cv2.rectangle(original_img, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)
    
    # 텍스트 위치 계산 및 조정
    text = f'object : {count}, acc : {conf:.2f}'
    font_scale = 2.0  # 텍스트 크기 조정
    font_thickness = 4  # 텍스트 두께 조정
    text_size, _ = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, font_scale, font_thickness)
    text_w, text_h = text_size
    text_x = int(x1)
    text_y = int(y1) - 10
    
    if text_y < text_h:
        text_y = int(y1) + text_h + 10
    
    # 텍스트 배경 그리기
    cv2.rectangle(original_img, (text_x, text_y - text_h), (text_x + text_w, text_y), (255, 0, 0), -1)
    # 텍스트 그리기
    cv2.putText(original_img, text, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (255, 255, 255), font_thickness)


results_folder = "result_pickle_notebo.ok"

# 0, 1, 10, 100 ... 과 같이 정렬되지 않고 0, 1, 2, 3, 4... 순으로 정렬되게 하기 위해서
sorted_result = sorted(os.listdir(results_folder), key=lambda s: int(re.search(r'\d+', s).group()))

# 저장된 모든 Results 객체 불러오기 및 시각화
for filename in sorted_result:
    file_path = os.path.join(results_folder, filename)
    with open(file_path, 'rb') as f:
        loaded_result = pickle.load(f)
    
    count = 0
    original_img = loaded_result.orig_img.copy()  # 원본 이미지 복사

    for box in loaded_result.boxes:
        x1, y1, x2, y2 = box.xyxy[0]  # 경계 상자 좌표
        conf = box.conf[0]
        cls = box.cls[0]
        label = loaded_result.names[int(cls)]

        if label == 'person':
            count += 1
            make_box(box,count,original_img)
            # 이 부분에 dataframe 만들고

    # 그림을 초기화하고 이미지 표시
    plt.figure()
    plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
    plt.show()

    select_object = int(input("Select object number (0 to continue): "))
    if select_object == 0:
        continue
    else:
        x1, y1, x2, y2 = loaded_result.boxes[select_object-1].xyxy[0]
        selected_img = loaded_result.orig_img.copy()

        make_box(loaded_result.boxes[select_object-1],select_object,selected_img)


        # 그림을 초기화하고 이미지 표시
        plt.figure()
        plt.imshow(cv2.cvtColor(selected_img, cv2.COLOR_BGR2RGB))
        plt.show()

# %%
import re
import matplotlib.pyplot as plt
import cv2
import os
import pickle
import numpy as np
from PIL import Image

def convert_to_yolo_format(x1, y1, x2, y2, img_width, img_height):
    center_x = (x1 + x2) / 2.0 / img_width
    center_y = (y1 + y2) / 2.0 / img_height
    width = (x2 - x1) / img_width
    height = (y2 - y1) / img_height
    return center_x, center_y, width, height

def split_and_savelabel(result, index, path, selected_img,filename):
    ori_img = selected_img

    x1, y1, x2, y2 = result.xyxy[0]  # 경계 상자 좌표
    
    img_idx=int(re.search(r'\d+', filename ).group())

    conf = result.conf[0]  # 정확도 가져오기
    cls = result.cls[0]  # 클래스 이름 가져오기
    label = loaded_result.names[int(cls)]  # 클래스 이름을 숫자로 변환

    print(0, float(x1), float(y1), float(x2), float(y2))

    print(type(ori_img))

    # BGR에서 RGB로 변환
    ori_img_rgb = cv2.cvtColor(ori_img, cv2.COLOR_BGR2RGB)
    numpy_to_PIL = Image.fromarray(ori_img_rgb)  # Numpy array to PIL image
    train_img_path = os.path.join(path, 'train/images', f'{img_idx}.jpg')

    numpy_to_PIL.save(train_img_path, 'JPEG')  # save PIL image

    img_height, img_width = ori_img.shape[:2]

    yolo_bbox = convert_to_yolo_format(x1, y1, x2, y2, img_width, img_height)

    train_label_path = os.path.join(path,'train/labels',f'{img_idx}.text')
    # 만약 파일이 없다면 만들고 쓸 파일을 open 하기
    f=open(train_label_path,"a+")
    
    with open(train_label_path,"a+") as f:
        f.write(f"0 {float(yolo_bbox[0])} {float(yolo_bbox[1])} {float(yolo_bbox[2])} {float(yolo_bbox[3])}\n")

    
def make_folder():
    # img와 label을 저장할 폴더
    img_label = "img_label_folder"

    # img_label에 넣을 train, test, val 폴더
    subfolders = ["train", "test", "val"]

    # train, test, val 폴더 안에 넣을 서브 폴더들
    sub_subfolders = ["images", "labels"]

    # img_label_folder 폴더 만들기
    if not os.path.exists(img_label):
        os.makedirs(img_label)

    # train, test, val 폴더 만들기
    for subfolder in subfolders:
        path = os.path.join(img_label, subfolder)
        if not os.path.exists(path):
            os.makedirs(path)
        for subsub in sub_subfolders:
            sub_path = os.path.join(path,subsub)
            if not os.path.exists(sub_path):
                os.makedirs(sub_path)
            print(sub_path)
        
    return img_label




# label의 배경과 글자 크기 설정 메서드
def make_box(result,count,original_img):
    x1, y1, x2, y2 = result.xyxy[0]  # 경계 상자 좌표
    conf = result.conf[0]
    cls = result.cls[0]
    label = loaded_result.names[int(cls)]

    # 경계 상자 그리기
    cv2.rectangle(original_img, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)
    
    # 텍스트 위치 계산 및 조정
    text = f'object : {count}, acc : {conf:.2f}'
    font_scale = 2.0  # 텍스트 크기 조정
    font_thickness = 4  # 텍스트 두께 조정
    text_size, _ = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, font_scale, font_thickness)
    text_w, text_h = text_size
    text_x = int(x1)
    text_y = int(y1) - 10
    
    if text_y < text_h:
        text_y = int(y1) + text_h + 10
    
    # 텍스트 배경 그리기
    cv2.rectangle(original_img, (text_x, text_y - text_h), (text_x + text_w, text_y), (255, 0, 0), -1)
    # 텍스트 그리기
    cv2.putText(original_img, text, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (255, 255, 255), font_thickness)



# 폴더 train, test, val 폴더 만들고 path는 img_label에 저장
img_label = make_folder()

# 저장된 pickle 데이터를 가져오기 위해 파일명 가져오기
results_folder = "result_pickle_notebook"

# 0, 1, 10, 100 ... 과 같이 정렬되지 않고 0, 1, 2, 3, 4... 순으로 정렬되게 하기 위해서
sorted_result = sorted(os.listdir(results_folder), key=lambda s: int(re.search(r'\d+', s).group()))

# 저장된 모든 Results 객체 불러오기 및 시각화
for filename in sorted_result:
    file_path = os.path.join(results_folder, filename)
    with open(file_path, 'rb') as f:
        loaded_result = pickle.load(f)
    
    count = 0
    original_img = loaded_result.orig_img.copy()  # 원본 이미지 복사

    for box in loaded_result.boxes:
        x1, y1, x2, y2 = box.xyxy[0]  # 경계 상자 좌표
        conf = box.conf[0]
        cls = box.cls[0]
        label = loaded_result.names[int(cls)]

        if label == 'person':
            count += 1
            make_box(box,count,original_img)


    # 그림을 초기화하고 이미지 표시
    plt.figure()
    plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
    plt.show()

    select_object = int(input("Select object number (0 to continue): "))
    if select_object == 0:
        continue
    else:
        x1, y1, x2, y2 = loaded_result.boxes[select_object-1].xyxy[0]
        selected_img = loaded_result.orig_img.copy()
        selected_ori_img = loaded_result.orig_img.copy()

        make_box(loaded_result.boxes[select_object-1],select_object,selected_img)
        
        # 이 부분에 dataframe 만들고 split 하기
        split_and_savelabel(loaded_result.boxes[select_object-1],select_object,img_label,selected_ori_img,filename)


        # 그림을 초기화하고 이미지 표시
        plt.figure()
        plt.imshow(cv2.cvtColor(selected_img, cv2.COLOR_BGR2RGB))
        plt.show()
        print(type(selected_img))

# %%
import re
import matplotlib.pyplot as plt
import cv2
import os
import pickle
from PIL import Image


def make_folder():
    # img와 label을 저장할 폴더
    img_label = "maid_tale_image_label"

    # img_label에 넣을 train, test, val 폴더
    subfolders = ["train", "test", "val"]

    # train, test, val 폴더 안에 넣을 서브 폴더들
    sub_subfolders = ["images", "labels"]

    # img_label_folder 폴더 만들기
    if not os.path.exists(img_label):
        os.makedirs(img_label)

    # train, test, val 폴더 만들기
    for subfolder in subfolders:
        path = os.path.join(img_label, subfolder)
        if not os.path.exists(path):
            os.makedirs(path)
        for subsub in sub_subfolders:
            sub_path = os.path.join(path, subsub)
            if not os.path.exists(sub_path):
                os.makedirs(sub_path)
            print(sub_path)
        
    return img_label


def convert_to_yolo_format(x1, y1, x2, y2, img_width, img_height): 
    center_x = (x1 + x2) / 2.0 / img_width
    center_y = (y1 + y2) / 2.0 / img_height
    width = (x2 - x1) / img_width
    height = (y2 - y1) / img_height
    return center_x, center_y, width, height

def split_and_savelabel(result, index, path, selected_img, filename):
    ori_img = selected_img

    x1, y1, x2, y2 = result.xyxy[0]  # 경계 상자 좌표
    
    img_idx = int(re.search(r'\d+', filename).group())

    conf = result.conf[0]  # 정확도 가져오기
    cls = result.cls[0]  # 클래스 이름 가져오기
    label = loaded_result.names[int(cls)]  # 클래스 이름을 숫자로 변환

    print(0, float(x1), float(y1), float(x2), float(y2))

    print(type(ori_img))

    # BGR에서 RGB로 변환
    ori_img_rgb = cv2.cvtColor(ori_img, cv2.COLOR_BGR2RGB)
    numpy_to_PIL = Image.fromarray(ori_img_rgb)  # Numpy array to PIL image
    train_img_path = os.path.join(path, 'train/images', f'{img_idx}.jpg')

    numpy_to_PIL.save(train_img_path, 'JPEG')  # save PIL image

    img_height, img_width = ori_img.shape[:2]

    yolo_bbox = convert_to_yolo_format(x1, y1, x2, y2, img_width, img_height)

    train_label_path = os.path.join(path, 'train/labels', f'{img_idx}.txt')
    
    # 라벨 파일을 YOLO 형식으로 저장
    with open(train_label_path, "a+") as f:
        f.write(f"0 {yolo_bbox[0]} {yolo_bbox[1]} {yolo_bbox[2]} {yolo_bbox[3]}\n")

# label의 배경과 글자 크기 설정 메서드
def make_box(result, count, original_img):
    x1, y1, x2, y2 = result.xyxy[0]  # 경계 상자 좌표
    conf = result.conf[0]
    cls = result.cls[0]
    label = loaded_result.names[int(cls)]

    # 경계 상자 그리기
    cv2.rectangle(original_img, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)
    
    # 텍스트 위치 계산 및 조정
    text = f'object : {count}, acc : {conf:.2f}'
    font_scale = 2.0  # 텍스트 크기 조정
    font_thickness = 4  # 텍스트 두께 조정
    text_size, _ = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, font_scale, font_thickness)
    text_w, text_h = text_size
    text_x = int(x1)
    text_y = int(y1) - 10
    
    if text_y < text_h:
        text_y = int(y1) + text_h + 10
    
    # 텍스트 배경 그리기
    cv2.rectangle(original_img, (text_x, text_y - text_h), (text_x + text_w, text_y), (255, 0, 0), -1)
    # 텍스트 그리기
    cv2.putText(original_img, text, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (255, 255, 255), font_thickness)

# 폴더 train, test, val 폴더 만들고 path는 img_label에 저장
img_label = make_folder()

# 저장된 pickle 데이터를 가져오기 위해 파일명 가져오기
results_folder = "result_pickle_maid"

# 0, 1, 10, 100 ... 과 같이 정렬되지 않고 0, 1, 2, 3, 4... 순으로 정렬되게 하기 위해서
sorted_result = sorted(os.listdir(results_folder), key=lambda s: int(re.search(r'\d+', s).group()))

# 저장된 모든 Results 객체 불러오기 및 시각화
for filename in sorted_result:
    file_path = os.path.join(results_folder, filename)
    with open(file_path, 'rb') as f:
        loaded_result = pickle.load(f)
    
    count = 0
    original_img = loaded_result.orig_img.copy()  # 원본 이미지 복사

    for box in loaded_result.boxes:
        x1, y1, x2, y2 = box.xyxy[0]  # 경계 상자 좌표
        conf = box.conf[0]
        cls = box.cls[0]
        label = loaded_result.names[int(cls)]

        if label == 'person':
            count += 1
            make_box(box, count, original_img)

    # 그림을 초기화하고 이미지 표시
    plt.figure()
    plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
    plt.show()

    select_object = int(input("Select object number (0 to continue): "))
    if select_object == 0:
        if os.path.exists(file_path):
            os.remove(file_path)
        continue
    else:

        try:
            x1, y1, x2, y2 = loaded_result.boxes[select_object-1].xyxy[0]
            selected_img = loaded_result.orig_img.copy()
            selected_ori_img = loaded_result.orig_img.copy()
            make_box(loaded_result.boxes[select_object-1], select_object, selected_img)
        
            # 이 부분에 dataframe 만들고 split 하기
            split_and_savelabel(loaded_result.boxes[select_object-1], select_object, img_label, selected_ori_img, filename)

            # 그림을 초기화하고 이미지 표시
            plt.figure()
            plt.imshow(cv2.cvtColor(selected_img, cv2.COLOR_BGR2RGB))
            plt.show()
            print(type(selected_img))
        except:
            if os.path.exists(file_path):
                os.remove(file_path)
            continue
        if os.path.exists(file_path):
            os.remove(file_path)
